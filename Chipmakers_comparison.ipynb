# %%
import pandas as pd 
import numpy as np
import yfinance as yf

# %%
start="2015-10-01"
end="2025-10-01"

# %%
symbol=["NVDA","KLAC","TSM","AVGO","AMD","QCOM"]

# %%
df=yf.download(symbol,start,end,multi_level_index=False)
df
# Out:
# C:\Users\rshaw\AppData\Local\Temp\ipykernel_44652\3874266172.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df=yf.download(symbol,start,end,multi_level_index=False)
# [*********************100%***********************]  6 of 6 completed
# Price           Close                                                          \
# Ticker            AMD       AVGO        KLAC       NVDA       QCOM        TSM
# Date
# 2015-10-01   1.740000   9.308363   41.204887   0.587338  39.730541  16.066788
# 2015-10-02   1.830000   9.399054   41.894398   0.602648  41.142555  15.989761
# 2015-10-05   1.800000   9.238250   42.974361   0.617714  42.009193  16.482700
# 2015-10-06   1.830000   8.925022   43.589123   0.625733  42.076427  16.351765
# 2015-10-07   1.860000   9.041628   43.755268   0.632294  42.293087  16.890919
# ...               ...        ...         ...        ...        ...        ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2514 entries, 2015-10-01 to 2025-09-30
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AMD)    2514 non-null   float64
#  1   (Close, AVGO)   2514 non-null   float64
#  2   (Close, KLAC)   2514 non-null   float64
#  3   (Close, NVDA)   2514 non-null   float64
#  4   (Close, QCOM)   2514 non-null   float64
#  5   (Close, TSM)    2514 non-null   float64
#  6   (High, AMD)     2514 non-null   float64
#  7   (High, AVGO)    2514 non-null   float64
#  8   (High, KLAC)    2514 non-null   float64
#  9   (High, NVDA)    2514 non-null   float64
#  10  (High, QCOM)    2514 non-null   float64
#  11  (High, TSM)     2514 non-null   float64
#  12  (Low, AMD)      2514 non-null   float64
#  13  (Low, AVGO)     2514 non-null   float64
#  14  (Low, KLAC)     2514 non-null   float64
#  15  (Low, NVDA)     2514 non-null   float64
# ...

# %%
df.to_csv("chipManufactureres.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format='{:4f}'.format
plt.style.use("seaborn")
# Out:
# C:\Users\rshaw\AppData\Local\Temp\ipykernel_44652\1106583151.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
pd.read_csv("chipManufactureres.csv",header=[0,1],index_col=0,parse_dates=[0])
# Out:
# Price           Close                                                          \
# Ticker            AMD       AVGO        KLAC       NVDA       QCOM        TSM
# Date
# 2015-10-01   1.740000   9.308363   41.204887   0.587338  39.730541  16.066788
# 2015-10-02   1.830000   9.399054   41.894398   0.602648  41.142555  15.989761
# 2015-10-05   1.800000   9.238250   42.974361   0.617714  42.009193  16.482700
# 2015-10-06   1.830000   8.925022   43.589123   0.625733  42.076427  16.351765
# 2015-10-07   1.860000   9.041628   43.755268   0.632294  42.293087  16.890919
# ...               ...        ...         ...        ...        ...        ...
# 2025-09-24 160.880005 338.662018 1066.880005 176.960144 172.667725 279.954224
# 2025-09-25 161.270004 335.458130 1057.325928 177.680115 168.817398 275.915131
# 2025-09-26 159.460007 333.891144 1062.507324 178.180084 168.339844 272.623993
# 2025-09-29 161.360001 327.273804 1062.347534 181.839890 164.459671 272.494385
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2514 entries, 2015-10-01 to 2025-09-30
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, AVG)    0 non-null      float64
#  1   (Adj Close, QCOMM)  0 non-null      float64
#  2   (Adj Close, TSMC)   0 non-null      float64
#  3   (Close, AMD)        2514 non-null   float64
#  4   (Close, AVG)        0 non-null      float64
#  5   (Close, KLAC)       2514 non-null   float64
#  6   (Close, NVDA)       2514 non-null   float64
#  7   (Close, QCOMM)      0 non-null      float64
#  8   (Close, TSMC)       0 non-null      float64
#  9   (High, AMD)         2514 non-null   float64
#  10  (High, AVG)         0 non-null      float64
#  11  (High, KLAC)        2514 non-null   float64
#  12  (High, NVDA)        2514 non-null   float64
#  13  (High, QCOMM)       0 non-null      float64
#  14  (High, TSMC)        0 non-null      float64
# ...

# %%
df.Close.AMD
# Out:
# Date
# 2015-10-01     1.740000
# 2015-10-02     1.830000
# 2015-10-05     1.800000
# 2015-10-06     1.830000
# 2015-10-07     1.860000
#                 ...
# 2025-09-24   160.880005
# 2025-09-25   161.270004
# 2025-09-26   159.460007
# 2025-09-29   161.360001
# 2025-09-30   161.789993
# Name: AMD, Length: 2514, dtype: float64

# %%
df.loc["2025-09-09"]
# Out:
# Price   Ticker
# Close   AMD            155.820007
#         AVGO           335.452332
#         KLAC           916.192749
#         NVDA           170.740860
#         QCOM           157.853424
#         TSM            249.457443
# High    AMD            156.660004
#         AVGO           349.710572
#         KLAC           921.204360
#         NVDA           170.960837
#         QCOM           160.778480
#         TSM            253.245233
# Low     AMD            151.929993
#         AVGO           334.615343
#         KLAC           908.705312
#         NVDA           166.721321
#         QCOM           156.768969
#         TSM            245.490695
# Open    AMD            151.990005
#         AVGO           348.285721
#         KLAC           909.224460
#         NVDA           169.071049
#         QCOM           159.554722
#         TSM            245.490695
# Volume  AMD       42802500.000000
#         AVGO      26972300.000000
#         KLAC        677800.000000
# ...

# %%
df=df.swaplevel(axis="columns").sort_index(axis="columns")
df
# Out:
# Price           Close                                                          \
# Ticker            AMD       AVGO        KLAC       NVDA       QCOM        TSM
# Date
# 2015-10-01   1.740000   9.308363   41.204887   0.587338  39.730541  16.066788
# 2015-10-02   1.830000   9.399054   41.894398   0.602648  41.142555  15.989761
# 2015-10-05   1.800000   9.238250   42.974361   0.617714  42.009193  16.482700
# 2015-10-06   1.830000   8.925022   43.589123   0.625733  42.076427  16.351765
# 2015-10-07   1.860000   9.041628   43.755268   0.632294  42.293087  16.890919
# ...               ...        ...         ...        ...        ...        ...
# 2025-09-24 160.880005 338.662018 1066.880005 176.960144 172.667725 279.954224
# 2025-09-25 161.270004 335.458130 1057.325928 177.680115 168.817398 275.915131
# 2025-09-26 159.460007 333.891144 1062.507324 178.180084 168.339844 272.623993
# 2025-09-29 161.360001 327.273804 1062.347534 181.839890 164.459671 272.494385
# ...

# %%
close=df.Close.copy()

# %%
close
# Out:
# Ticker            AMD       AVGO        KLAC       NVDA       QCOM        TSM
# Date
# 2015-10-01   1.740000   9.308363   41.204887   0.587338  39.730541  16.066788
# 2015-10-02   1.830000   9.399054   41.894398   0.602648  41.142555  15.989761
# 2015-10-05   1.800000   9.238250   42.974361   0.617714  42.009193  16.482700
# 2015-10-06   1.830000   8.925022   43.589123   0.625733  42.076427  16.351765
# 2015-10-07   1.860000   9.041628   43.755268   0.632294  42.293087  16.890919
# ...               ...        ...         ...        ...        ...        ...
# 2025-09-24 160.880005 338.662018 1066.880005 176.960144 172.667725 279.954224
# 2025-09-25 161.270004 335.458130 1057.325928 177.680115 168.817398 275.915131
# 2025-09-26 159.460007 333.891144 1062.507324 178.180084 168.339844 272.623993
# 2025-09-29 161.360001 327.273804 1062.347534 181.839890 164.459671 272.494385
# 2025-09-30 161.789993 329.279968 1076.793335 186.569611 165.514282 278.538055
#
# [2514 rows x 6 columns]

# %%
close.describe()
# Out:
# Ticker         AMD        AVGO        KLAC        NVDA        QCOM         TSM
# count  2514.000000 2514.000000 2514.000000 2514.000000 2514.000000 2514.000000
# mean     67.856221   60.819959  295.335986   31.326406   95.658047   78.632399
# std      53.181898   67.649418  244.978017   45.336230   45.947020   56.868636
# min       1.740000    8.643807   41.204887    0.587338   32.412079   15.774096
# 25%      13.820000   19.500370   92.259920    4.185073   49.148485   32.445423
# 50%      67.695000   32.079729  193.589333   12.463035  100.999409   71.197639
# 75%     107.567499   60.465517  399.656731   29.315711  132.810104  107.811426
# max     211.380005  368.233337 1076.793335  186.569611  219.826035  281.948853

# %%
close.plot(figsize=(15,8),fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 1.7400000095367432

# %%
norm=close.div(close.iloc[0]).mul(100)
norm
# Out:
# Ticker             AMD        AVGO        KLAC         NVDA       QCOM  \
# Date
# 2015-10-01  100.000000  100.000000  100.000000   100.000000 100.000000
# 2015-10-02  105.172416  100.974292  101.673370   102.606582 103.553976
# 2015-10-05  103.448273   99.246772  104.294330   105.171729 105.735266
# 2015-10-06  105.172416   95.881759  105.786293   106.537067 105.904491
# 2015-10-07  106.896552   97.134458  106.189510   107.654147 106.449813
# ...                ...         ...         ...          ...        ...
# 2025-09-24 9245.977241 3638.255397 2589.207428 30129.172815 434.596961
# 2025-09-25 9268.390999 3603.835941 2566.020671 30251.754777 424.905860
# 2025-09-26 9164.368152 3587.001766 2578.595384 30336.879408 423.703878
# 2025-09-29 9273.563203 3515.911499 2578.207590 30959.996590 413.937656
# 2025-09-30 9298.275425 3537.463780 2613.266054 31765.277261 416.592065
#
# Ticker             TSM
# Date
# 2015-10-01  100.000000
# 2015-10-02   99.520586
# 2015-10-05  102.588648
# ...

# %%
norm.plot(figsize=(15,8),fontsize=13,logy=True)
plt.legend(fontsize=13)
plt.show()
